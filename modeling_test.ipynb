# %%
import pandas as pd

# %%
pip install kaggle
# Out:
# ...
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script slugify is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 4/5 [kaggle]f]  WARNING: The script kaggle is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [kaggle]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Baixa o dataset diretamente do Kaggle
# !kaggle datasets download -d xontoloyo/data-penjualan-zara
# Out:
# Dataset URL: https://www.kaggle.com/datasets/xontoloyo/data-penjualan-zara
# License(s): MIT
# ...
#   0%|                                               | 0.00/16.8k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 16.8k/16.8k [00:00<00:00, 44.5MB/s]

# %%
# Descompacta o arquivo zip (cria uma pasta com os dados)
# !unzip -o data-penjualan-zara.zip -d data_penjualan_zara
# Out:
# Archive:  data-penjualan-zara.zip
#   inflating: data_penjualan_zara/zara.csv

# %%
df = pd.read_csv("data_penjualan_zara/zara.csv", sep=";")
df.head()
# Out:
#    Product ID Product Position Promotion Product Category Seasonal  \
# 0      185102            Aisle        No         Clothing       No
# 1      188771            Aisle        No         Clothing       No
# 2      180176          End-cap       Yes         Clothing      Yes
# 3      112917            Aisle       Yes         Clothing      Yes
# 4      192936          End-cap        No         Clothing      Yes
#
#    Sales Volume brand                                                url  \
# 0          2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1           654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          2220  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1568  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          2942  Zara  https://www.zara.com/us/en/double-faced-jacket...
#
#                 sku                  name  \
# 0   272145190-250-2   BASIC PUFFER JACKET
# ...
