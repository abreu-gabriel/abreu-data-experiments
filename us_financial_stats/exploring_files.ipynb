# %%
import csv

# %%
# pure python
with open("fed_funds_rate.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    # for row in reader:
    #     print(row)
    row_count = sum(1 for row in reader)
    print(f"Total number of rows: {row_count}")
# Out:
# Total number of rows: 2558

# %%
import pandas as pd
# using pandas
file_path = 'fed_funds_rate.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   realtime_start realtime_end        date  value
# 0     2026-01-31   2026-01-31  2019-01-01    2.4
# 1     2026-01-31   2026-01-31  2019-01-02    2.4
# 2     2026-01-31   2026-01-31  2019-01-03    2.4
# 3     2026-01-31   2026-01-31  2019-01-04    2.4
# 4     2026-01-31   2026-01-31  2019-01-05    2.4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   realtime_start  2557 non-null   str
#  1   realtime_end    2557 non-null   str
#  2   date            2557 non-null   str
#  3   value           2557 non-null   float64
# dtypes: float64(1), str(3)
# memory usage: 80.0 KB
