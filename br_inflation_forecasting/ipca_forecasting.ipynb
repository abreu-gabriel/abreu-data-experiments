# %%
import csv
import pandas as pd

# %%
# pure python
with open("us_cpi.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    row_count = sum(1 for row in reader)
    print(f"Total number of rows: {row_count}")
# Out:
# Total number of rows: 301

# %%
file_path = 'us_cpi.csv'
df_cpi = pd.read_csv(file_path)
print(df_cpi.head())
# Out:
#   realtime_start realtime_end        date  value
# 0     2026-02-28   2026-02-28  2000-01-01  168.8
# 1     2026-02-28   2026-02-28  2000-02-01  169.8
# 2     2026-02-28   2026-02-28  2000-03-01  171.2
# 3     2026-02-28   2026-02-28  2000-04-01  171.3
# 4     2026-02-28   2026-02-28  2000-05-01  171.5
